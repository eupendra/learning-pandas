# %% [markdown]
# # Importing Data
# * https://www.kaggle.com/uciml/iris
# * http://archive.ics.uci.edu/ml/datasets/Iris

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.set_index("Id")
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.set_index("Id", inplace=True)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = pd.read_csv("Data/Iris.csv", index_col=0)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = pd.read_excel("Data/Iris.xlsx", index_col=0)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
pd.read_csv("Data/Iris_tab.csv",sep="\t",index_col=0) #tab sep CSV
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
pd.read_table("Data/uci/iris.data",
              sep=",",
              header=None,
              names=['SepalLength Cm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
             ) #Same as read_csv, just with different defaults
# Out:
#      SepalLength Cm  SepalWidthCm  PetalLengthCm    PetalWidthCm
# 5.1             3.5           1.4            0.2     Iris-setosa
# 4.9             3.0           1.4            0.2     Iris-setosa
# 4.7             3.2           1.3            0.2     Iris-setosa
# 4.6             3.1           1.5            0.2     Iris-setosa
# 5.0             3.6           1.4            0.2     Iris-setosa
# ..              ...           ...            ...             ...
# 6.7             3.0           5.2            2.3  Iris-virginica
# 6.3             2.5           5.0            1.9  Iris-virginica
# 6.5             3.0           5.2            2.0  Iris-virginica
# 6.2             3.4           5.4            2.3  Iris-virginica
# 5.9             3.0           5.1            1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
pd.read_clipboard(sep=",",index_col=0) #output will depend on what you have on clipboard
# Out:
#                sepal_width  petal_length  petal_width           class
# sepal_length
# 5.1                    3.5           1.4          0.2     Iris-setosa
# 4.9                    3.0           1.4          0.2     Iris-setosa
# 4.7                    3.2           1.3          0.2     Iris-setosa
# 4.6                    3.1           1.5          0.2     Iris-setosa
# 5.0                    3.6           1.4          0.2     Iris-setosa
# ...                    ...           ...          ...             ...
# 6.7                    3.0           5.2          2.3  Iris-virginica
# 6.3                    2.5           5.0          1.9  Iris-virginica
# 6.5                    3.0           5.2          2.0  Iris-virginica
# 6.2                    3.4           5.4          2.3  Iris-virginica
# 5.9                    3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/Timeline_of_programming_languages')

# %%
type(dfs)
# Out:
# list

# %%
dfs[10]
# Out:
#     Year                                 Name  \
# 0   2000                            Join Java
# 1   2000                            DarkBasic
# 2   2000                                   C#
# 3   2001                                  Joy
# 4   2001                              AspectJ
# 5   2001                                    D
# 6   2001                           Processing
# 7   2001                    Visual Basic .NET
# 8   2001                       GDScript (GDS)
# 9   2001     Shakespeare Programming Language
# 10  2002                                   Io
# 11  2002                                 Gosu
# 12  2002                              Scratch
# 13  2003                              Nemerle
# 14  2003                               Factor
# 15  2003                                Scala
# 16  2003                                C++03
# 17  2003                             Squirrel
# 18  2003                                  Boo
# ...

# %%
import sqlite3

# %%
con = sqlite3.connect("Data/database.sqlite")
df = pd.read_sql_query('select * from iris',con)
con.close()

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
